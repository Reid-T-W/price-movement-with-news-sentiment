# %%
import pandas as pd
df_aapl = pd.read_csv(r'../data/raw/yfinance_data/AAPL_historical_data.csv')
df_amzn = pd.read_csv(r'../data/raw/yfinance_data/AMZN_historical_data.csv')
df_goog = pd.read_csv(r'../data/raw/yfinance_data/GOOG_historical_data.csv')
df_meta = pd.read_csv(r'../data/raw/yfinance_data/META_historical_data.csv')
df_msft = pd.read_csv(r'../data/raw/yfinance_data/MSFT_historical_data.csv')
df_nvda = pd.read_csv(r'../data/raw/yfinance_data/NVDA_historical_data.csv')
df_tsla = pd.read_csv(r'../data/raw/yfinance_data/TSLA_historical_data.csv')

financial_dataframes = [["aapl", df_aapl], ["amzn", df_amzn], ["goog", df_goog], ["meta", df_meta], ["msft", df_msft], ["nvda", df_nvda], ["tsla", df_tsla]]

# %%
df_aapl.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 1980-12-12  0.128348  0.128906  0.128348  0.128348   0.098943  469033600
# 1980-12-15  0.122210  0.122210  0.121652  0.121652   0.093781  175884800
# 1980-12-16  0.113281  0.113281  0.112723  0.112723   0.086898  105728000
# 1980-12-17  0.115513  0.116071  0.115513  0.115513   0.089049   86441600
# 1980-12-18  0.118862  0.119420  0.118862  0.118862   0.091630   73449600
#
#             Dividends  Stock Splits    SMA_5
# Date
# 1980-12-12        0.0           0.0      NaN
# 1980-12-15        0.0           0.0      NaN
# 1980-12-16        0.0           0.0      NaN
# 1980-12-17        0.0           0.0      NaN
# 1980-12-18        0.0           0.0  0.11942

# %%
def describe_data(df):
    print("------------------------------------")
    print(f"TICKER {df[0]}")
    print(df[1].describe())

# %%
for df in financial_dataframes:
    describe_data(df)
# Out:
# ------------------------------------
# TICKER aapl
#                Open          High           Low         Close     Adj Close  \
# count  10998.000000  10998.000000  10998.000000  10998.000000  10998.000000
# mean      22.299160     22.539055     22.068367     22.312754     21.494496
# std       46.003685     46.496031     45.540929     46.037660     45.561916
# min        0.049665      0.049665      0.049107      0.049107      0.037857
# 25%        0.299107      0.303710      0.290179      0.298549      0.241840
# 50%        0.531250      0.537946      0.522321      0.531250      0.432079
# 75%       20.204196     20.389554     19.998036     20.196160     17.253029
# max      236.479996    237.229996    233.089996    234.820007    234.548523
#
#              Volume     Dividends  Stock Splits
# count  1.099800e+04  10998.000000  10998.000000
# mean   3.180806e+08      0.000752      0.001546
# std    3.354523e+08      0.011753      0.083663
# ...

# %%
# import matplotlib.pyplot as plt
# from mpl_finance import candlestick_ochl, candlesticks

# %%
import talib
import mplfinance as mpf

def plot_sma(df):
    # Prepare your DataFrame
    df[1].index = pd.to_datetime(df[1].index)
    # df[1].set_index('Date', inplace=True)

    # Calculate the 5-period SMA
    df[1]['SMA_5'] = talib.SMA(df[1]['Close'], timeperiod=5)

    # Plot candlestick chart with SMA overlay
    mpf.plot(
        df[1],
        type='candle',
        mav=(5,),         # Moving average window(s)
        volume=True,      # Show volume subplot
        title=f'{df[0].upper()} Candlestick with 5-period SMA'
    )
    # sma = talib.SMA(df.Close,5)
    # candlestick_ochl(df)
    # plt.plot(sma, 'k')

# %%
for df in financial_dataframes:
    plot_sma(df)
# Out:
# d:\Software Career\Kifiya 10 Academy\week1\price-movement-with-news-sentiment\env\lib\site-packages\mplfinance\_arg_validators.py:84: UserWarning:
#
# ...
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
# ...
#   warnings.warn('\n\n ================================================================= '+
# d:\Software Career\Kifiya 10 Academy\week1\price-movement-with-news-sentiment\env\lib\site-packages\mplfinance\_arg_validators.py:84: UserWarning:
#
# ...
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
# ...

# %% [markdown]
# #### RSI

# %%
import matplotlib.pyplot as plt
import talib

# %%
from matplotlib.pyplot import spy


def plot_rsi(df):
    print("------------------------------------")    
    plt.figure(figsize=[10,7])
    rsi = talib.RSI(df[1].Close, 14)
    plt.plot(rsi)
    plt.title(f"RSI for {df[0].upper()}")
    plt.xlabel("Index")
    plt.ylabel("RSI")
    plt.show()

# %%
for df in financial_dataframes:
    plot_rsi(df)
# Out:
# ------------------------------------
# ------------------------------------
# ------------------------------------
# ------------------------------------
# ------------------------------------
# ------------------------------------
# ------------------------------------

# %% [markdown]
# #### MACD

# %%
import talib
import matplotlib.pyplot as plt

def plot_macd(df):
    # Calculate MACD
    macd, sig, hist = talib.MACD(df[1].Close, fastperiod=12, slowperiod=26, signalperiod=9)

    # Plot the MACD, Signal line, and Histogram
    plt.figure(figsize=[10, 7])
    plt.xticks(rotation=45, fontsize=18)
    plt.yticks(fontsize=18)
    plt.plot(macd, 'b-', sig, 'r-', hist, 'g-')
    plt.title(f"MACD for {df[0].upper()}")
    plt.show()

# %%
for df in financial_dataframes:
    plot_macd(df)
